# %% [markdown]
# <a href="https://colab.research.google.com/github/Usama1039/ISYS5002_2023_S2_Thursday/blob/main/05_2.2_using_paycalc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import paycalc module

# %%
import paycalc_module as pay
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
help(pay)
# Out:
# Help on module paycalc_module:
#
# NAME
#     paycalc_module - 05_2.1_paycalc_module.ipynb
#
# DESCRIPTION
#     Automatically generated by Colaboratory.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1UG9Qrr0KskcCle6ZqS7QPwecJoyCTbo3
#
# FUNCTIONS
#     calculate_pay(salary, sales, comm)
#         This function calculates the commission, tax, and pay for a given salary, sales, and commission rate.
#
#         Inputs:
#         salary: an integer representing the user's salary
#         sales: an integer representing the user's sales
#         comm: a float representing the user's commission rate
#
#         Returns:
#         commission: a float representing the commission earned based on the sales and commission rate
#         tax: a float representing the tax amount calculated based on the salary and commission earned
#         pay: a float representing the pay after deducting tax from the salary and adding the commission earned
#
# ...

# %% [markdown]
# ## call the relevant functions from the `paycalc` module to
# * get user input
# * calculate the pay
# * print the payslip

# %%
pay.user_input()
# Out:
# Please enter name: Usama
# Please enter salary: 28000
# Please enter sales: 2300
# Please enter commission rate: 9
# ('Usama', 28000, 2300, 9.0)

# %%
name, salary, sale, commission = pay.user_input()
# Out:
# Please enter name: Osama
# Please enter salary: 90000
# Please enter sales: 8700
# Please enter commission rate: 8

# %%
print(name)
print(salary)
print(sale)
# Out:
# Osama
# 90000
# 8700

# %%
comm_result, tax_result, pay_result = pay.calculate_pay(salary, sale, commission)

# %%
pay.print_payslip(name, salary, comm_result, tax_result, pay_result)
# Out:
# === Payslip of Osama ===
# Salary:     90000
# Commission: 696.0
# Tax:      19714.72
# Total pay: 70981.28

# %%
name, salary, sale, commission = pay.user_input()
pay.calculate_pay(salary, sale, commission)
pay.print_payslip(name, salary, comm_result, tax_result, pay_result)
# Out:
# Please enter name: Umer
# Please enter salary: 45000
# Please enter sales: 3400
# Please enter commission rate: 4
#
# === Payslip of Umer ===
# Salary:     45000
# Commission: 696.0
# Tax:      19714.72
# Total pay: 70981.28
